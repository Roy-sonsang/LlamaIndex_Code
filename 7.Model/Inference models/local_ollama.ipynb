# %%
pip install llama-index-llms-ollama
# Out:
# Collecting llama-index-llms-ollama
#   Downloading llama_index_llms_ollama-0.5.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.4 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-llms-ollama) (0.12.8)
# Collecting ollama>=0.4.3 (from llama-index-llms-ollama)
#   Downloading ollama-0.4.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (3.10.10)
# Requirement already satisfied: dataclasses-json in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2024.10.0)
# Requirement already satisfied: httpx in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (3.9.1)
# Requirement already satisfied: numpy in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (10.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (4.66.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (0.9.0)
# Requirement already satisfied: wrapt in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.17.1)
# Requirement already satisfied: anyio in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (4.6.2.post1)
# Requirement already satisfied: certifi in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.0.6)
# Requirement already satisfied: idna in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (3.10)
# Requirement already satisfied: sniffio in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (0.14.0)
# Requirement already satisfied: click in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (8.1.7)
# Requirement already satisfied: joblib in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (3.23.1)
# Requirement already satisfied: packaging>=17.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (24.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (0.2.0)
# Downloading llama_index_llms_ollama-0.5.0-py3-none-any.whl (6.7 kB)
# Downloading ollama-0.4.4-py3-none-any.whl (13 kB)
# Installing collected packages: ollama, llama-index-llms-ollama
# Successfully installed llama-index-llms-ollama-0.5.0 ollama-0.4.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from llama_index.llms.ollama import Ollama

ollama_model = Ollama(model="llama3.1")

print(ollama_model.complete("Hello, how are you?"))
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[2], line 5
#       1 from llama_index.llms.ollama import Ollama
#       3 ollama_model = Ollama(model="llama3.1")
# ----> 5 print(ollama_model.complete("Hello, how are you?"))
#
# File ~/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File ~/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages/llama_index/core/llms/callbacks.py:431, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#     422 event_id = callback_manager.on_event_start(
#     423     CBEventType.LLM,
#     424     payload={
#    (...)
#     428     },
#     429 )
#     430 try:
# --> 431     f_return_val = f(_self, *args, **kwargs)
#     432 except BaseException as e:
#     433     callback_manager.on_event_end(
#     434         CBEventType.LLM,
#     435         payload={EventPayload.EXCEPTION: e},
#     436         event_id=event_id,
#     437     )
#
# File ~/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages/llama_index/llms/ollama/base.py:465, in Ollama.complete(self, prompt, formatted, **kwargs)
#     461 @llm_completion_callback()
#     462 def complete(
#     463     self, prompt: str, formatted: bool = False, **kwargs: Any
#     464 ) -> CompletionResponse:
# --> 465     return chat_to_completion_decorator(self.chat)(prompt, **kwargs)
#
# File ~/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages/llama_index/core/base/llms/generic_utils.py:173, in chat_to_completion_decorator.<locals>.wrapper(prompt, **kwargs)
#     170 def wrapper(prompt: str, **kwargs: Any) -> CompletionResponse:
#     171     # normalize input
#     172     messages = prompt_to_messages(prompt)
# --> 173     chat_response = func(messages, **kwargs)
#     174     # normalize output
#     175     return chat_response_to_completion_response(chat_response)
#
# File ~/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File ~/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages/llama_index/core/llms/callbacks.py:173, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat(_self, messages, **kwargs)
#     164 event_id = callback_manager.on_event_start(
#     165     CBEventType.LLM,
#     166     payload={
#    (...)
#     170     },
#     171 )
#     172 try:
# --> 173     f_return_val = f(_self, messages, **kwargs)
#     174 except BaseException as e:
#     175     callback_manager.on_event_end(
#     176         CBEventType.LLM,
#     177         payload={EventPayload.EXCEPTION: e},
#     178         event_id=event_id,
#     179     )
#
# File ~/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages/llama_index/llms/ollama/base.py:306, in Ollama.chat(self, messages, **kwargs)
#     303 tools = kwargs.pop("tools", None)
#     304 format = kwargs.pop("format", "json" if self.json_mode else None)
# --> 306 response = self.client.chat(
#     307     model=self.model,
#     308     messages=ollama_messages,
#     309     stream=False,
#     310     format=format,
#     311     tools=tools,
#     312     options=self._model_kwargs,
#     313     keep_alive=self.keep_alive,
#     314 )
#     316 response = dict(response)
#     318 tool_calls = response["message"].get("tool_calls", [])
#
# File ~/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages/ollama/_client.py:332, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     288 def chat(
#     289   self,
#     290   model: str = '',
#    (...)
#     297   keep_alive: Optional[Union[float, str]] = None,
#     298 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     299   """
#     300   Create a chat response using the requested model.
#     301
#    (...)
#     330   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     331   """
# --> 332   return self._request(
#     333     ChatResponse,
#     334     'POST',
#     335     '/api/chat',
#     336     json=ChatRequest(
#     337       model=model,
#     338       messages=[message for message in _copy_messages(messages)],
#     339       tools=[tool for tool in _copy_tools(tools)],
#     340       stream=stream,
#     341       format=format,
#     342       options=options,
#     343       keep_alive=keep_alive,
#     344     ).model_dump(exclude_none=True),
#     345     stream=stream,
#     346   )
#
# File ~/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages/ollama/_client.py:177, in Client._request(self, cls, stream, *args, **kwargs)
#     173         yield cls(**part)
#     175   return inner()
# --> 177 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages/ollama/_client.py:122, in Client._request_raw(self, *args, **kwargs)
#     120   r.raise_for_status()
#     121 except httpx.HTTPStatusError as e:
# --> 122   raise ResponseError(e.response.text, e.response.status_code) from None
#     123 return r
#
# ResponseError: model "llama3.1" not found, try pulling it first
