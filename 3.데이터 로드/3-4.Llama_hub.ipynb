# %% [markdown]
# ### 1. SimpleWebPageReader

# %% [markdown]
# step1. 관련 라이브러리 설치

# %%
pip install llama-index-readers-web
# Out:
# Collecting llama-index-readers-web
#   Using cached llama_index_readers_web-0.2.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-readers-web) (3.10.10)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-readers-web) (4.12.3)
# Collecting chromedriver-autoinstaller<0.7.0,>=0.6.3 (from llama-index-readers-web)
#   Using cached chromedriver_autoinstaller-0.6.4-py3-none-any.whl.metadata (2.1 kB)
# Collecting html2text<2025.0.0,>=2024.2.26 (from llama-index-readers-web)
#   Using cached html2text-2024.2.26-py3-none-any.whl
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-readers-web) (0.11.21)
# Collecting newspaper3k<0.3.0,>=0.2.8 (from llama-index-readers-web)
#   Using cached newspaper3k-0.2.8-py3-none-any.whl.metadata (11 kB)
# Collecting playwright<2.0,>=1.30 (from llama-index-readers-web)
#   Using cached playwright-1.48.0-py3-none-macosx_11_0_universal2.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-readers-web) (2.32.3)
# Collecting selenium<5.0.0,>=4.17.2 (from llama-index-readers-web)
#   Downloading selenium-4.26.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting spider-client<0.0.28,>=0.0.27 (from llama-index-readers-web)
#   Using cached spider_client-0.0.27-py3-none-any.whl
# Requirement already satisfied: urllib3>=1.1.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-readers-web) (2.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-web) (2.6)
# Requirement already satisfied: packaging>=23.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from chromedriver-autoinstaller<0.7.0,>=0.6.3->llama-index-readers-web) (24.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (2.0.36)
# Requirement already satisfied: dataclasses-json in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (2024.10.0)
# Requirement already satisfied: httpx in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (4.66.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (0.9.0)
# Requirement already satisfied: wrapt in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (1.16.0)
# Collecting cssselect>=0.9.2 (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Using cached cssselect-1.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting lxml>=3.6.0 (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Using cached lxml-5.3.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (3.8 kB)
# Collecting feedparser>=5.2.1 (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Using cached feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Collecting tldextract>=2.0.1 (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Downloading tldextract-5.1.3-py3-none-any.whl.metadata (11 kB)
# Collecting feedfinder2>=0.0.4 (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Using cached feedfinder2-0.0.4-py3-none-any.whl
# Collecting jieba3k>=0.35.1 (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Using cached jieba3k-0.35.1-py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (2.9.0.post0)
# Collecting tinysegmenter==0.3 (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Using cached tinysegmenter-0.3-py3-none-any.whl
# Requirement already satisfied: greenlet==3.1.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from playwright<2.0,>=1.30->llama-index-readers-web) (3.1.1)
# Collecting pyee==12.0.0 (from playwright<2.0,>=1.30->llama-index-readers-web)
#   Using cached pyee-12.0.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->llama-index-readers-web) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->llama-index-readers-web) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->llama-index-readers-web) (2024.8.30)
# Collecting trio~=0.17 (from selenium<5.0.0,>=4.17.2->llama-index-readers-web)
#   Using cached trio-0.27.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting trio-websocket~=0.9 (from selenium<5.0.0,>=4.17.2->llama-index-readers-web)
#   Using cached trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: websocket-client~=1.8 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from selenium<5.0.0,>=4.17.2->llama-index-readers-web) (1.8.0)
# Requirement already satisfied: six in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from feedfinder2>=0.0.4->newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (1.16.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Using cached sgmllib3k-1.0.0-py3-none-any.whl
# Requirement already satisfied: click in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (8.1.7)
# Requirement already satisfied: joblib in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (2.23.4)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Using cached requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from tldextract>=2.0.1->newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (3.16.1)
# Collecting sortedcontainers (from trio~=0.17->selenium<5.0.0,>=4.17.2->llama-index-readers-web)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting outcome (from trio~=0.17->selenium<5.0.0,>=4.17.2->llama-index-readers-web)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from trio~=0.17->selenium<5.0.0,>=4.17.2->llama-index-readers-web) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium<5.0.0,>=4.17.2->llama-index-readers-web)
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (1.0.0)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium<5.0.0,>=4.17.2->llama-index-readers-web)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (0.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (3.23.1)
# Requirement already satisfied: anyio in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/LlamaIndex_Codes/llamaindex_env/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-web) (0.14.0)
# Using cached llama_index_readers_web-0.2.4-py3-none-any.whl (76 kB)
# Using cached chromedriver_autoinstaller-0.6.4-py3-none-any.whl (7.6 kB)
# Using cached newspaper3k-0.2.8-py3-none-any.whl (211 kB)
# Using cached playwright-1.48.0-py3-none-macosx_11_0_universal2.whl (35.0 MB)
# Using cached pyee-12.0.0-py3-none-any.whl (14 kB)
# Downloading selenium-4.26.1-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 10.8 MB/s eta 0:00:00a 0:00:01
# Using cached cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Using cached feedparser-6.0.11-py3-none-any.whl (81 kB)
# Using cached lxml-5.3.0-cp311-cp311-macosx_10_9_x86_64.whl (4.4 MB)
# Downloading tldextract-5.1.3-py3-none-any.whl (104 kB)
# Using cached trio-0.27.0-py3-none-any.whl (481 kB)
# Using cached trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: tinysegmenter, sortedcontainers, sgmllib3k, jieba3k, wsproto, pysocks, pyee, outcome, lxml, html2text, feedparser, cssselect, chromedriver-autoinstaller, trio, spider-client, requests-file, playwright, feedfinder2, trio-websocket, tldextract, selenium, newspaper3k, llama-index-readers-web
# Successfully installed chromedriver-autoinstaller-0.6.4 cssselect-1.2.0 feedfinder2-0.0.4 feedparser-6.0.11 html2text-2024.2.26 jieba3k-0.35.1 llama-index-readers-web-0.2.4 lxml-5.3.0 newspaper3k-0.2.8 outcome-1.3.0.post0 playwright-1.48.0 pyee-12.0.0 pysocks-1.7.1 requests-file-2.1.0 selenium-4.26.1 sgmllib3k-1.0.0 sortedcontainers-2.4.0 spider-client-0.0.27 tinysegmenter-0.3 tldextract-5.1.3 trio-0.27.0 trio-websocket-0.11.1 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# step2. 관련 라이브러리 불러오기

# %%
from llama_index.readers.web import SimpleWebPageReader

# %% [markdown]
# step3. 특정 url 웹 페이지 html 정보 로드

# %%
# 웹 페이지 로드
documents = SimpleWebPageReader().load_data(urls=["https://www.naver.com"])

print(documents)
# Out:
# [Document(id_='https://www.naver.com', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="google-site-verification" content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g"/> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"> <link rel="apple-touch-icon-precomposed" href="https://s.pstatic.net/static/www/nFavicon96.png"/> <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_240801.css"> <link rel="canonical" href="https://www.naver.com/"> <link rel="alternate" media="only screen and (max-width: 767px)" href="https://m.naver.com/"> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script>window.ntm=window.ntm||[]</script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>  <script>\nwindow["EAGER-DATA"] = window["EAGER-DATA"] || {};\nwindow["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-CAS-EDIT-CONTENTS-BLOCK","blocks":null,"materials":[{"@type":"MATERIAL-PC-FEED-EDIT","title":"볼보 시승신청","url":"https://www.volvocar.co.kr/buy/purchase/test-drive-campaign-for-all-models/?type=digital&source=naver&utm_source=naver_nosp&utm_medium=display&utm_content=electrification_display-ads_autotestdrive&utm_campaign=kr_electrification_consideration-action_2411_nameplates_other_digital_csi_paid&sourceapplicationinformation=kr_elc_cat_npl","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20241031_1095/upload_1730368303709hfwOW.jpg"},"highlight":"네이버 자동차","adMark":true,"desc":"시승 가능한 모델을 버튼으로 확인하세요!","clickCode":"vovol","_id":"6548800558a9ce6eb3e8a64e"},{"@type":"MATERIAL-PC-FEED-EDIT","title":"르노 시승신청","url":"https://naver.me/xHgia4eK","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20241008_1095/upload_17283612153890ZnfV.jpg"},"highlight":"네이버 자동차","adMark":true,"desc":"시승 가능한 모델을 버튼으로 확인하세요!","clickCode":"RE","_id":"6548800558a9ce6eb3e8a64f"},{"@type":"MATERIAL-PC-FEED-EDIT","title":"푸조시승신청","url":"https://naver.me/5du2DA4H","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20241002_1095/upload_1727852341038QhOet.jpg"},"highlight":"네이버 자동차","adMark":true,"desc ...

# %% [markdown]
# ### 2. Youtube Transcript Loader

# %% [markdown]
# step1. 관련 라이브러리 설치

# %%
pip install llama-hub-youtube-transcript llama-index-readers-youtube-transcript
# Out:
# Requirement already satisfied: llama-hub-youtube-transcript in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (0.0.1)
# Collecting llama-index-readers-youtube-transcript
#   Downloading llama_index_readers_youtube_transcript-0.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: requests-html in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-hub-youtube-transcript) (0.10.0)
# Requirement already satisfied: requests in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-hub-youtube-transcript) (2.32.3)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-readers-youtube-transcript) (0.11.17)
# Collecting youtube-transcript-api>=0.5.0 (from llama-index-readers-youtube-transcript)
#   Downloading youtube_transcript_api-0.6.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (3.10.8)
# Requirement already satisfied: dataclasses-json in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (2024.9.0)
# Requirement already satisfied: httpx in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (3.3)
# Requirement already satisfied: nltk>3.8.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (0.9.0)
# Requirement already satisfied: wrapt in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from requests->llama-hub-youtube-transcript) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from requests->llama-hub-youtube-transcript) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from requests->llama-hub-youtube-transcript) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from requests->llama-hub-youtube-transcript) (2024.8.30)
# Requirement already satisfied: pyquery in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from requests-html->llama-hub-youtube-transcript) (2.0.1)
# Requirement already satisfied: fake-useragent in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from requests-html->llama-hub-youtube-transcript) (1.5.1)
# Requirement already satisfied: parse in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from requests-html->llama-hub-youtube-transcript) (1.20.2)
# Requirement already satisfied: bs4 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from requests-html->llama-hub-youtube-transcript) (0.0.2)
# Requirement already satisfied: w3lib in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from requests-html->llama-hub-youtube-transcript) (2.2.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from requests-html->llama-hub-youtube-transcript) (2.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (1.13.1)
# Requirement already satisfied: click in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (8.1.7)
# Requirement already satisfied: joblib in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (2.23.4)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html->llama-hub-youtube-transcript) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html->llama-hub-youtube-transcript) (6.11.0)
# Requirement already satisfied: pyee<12.0.0,>=11.0.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html->llama-hub-youtube-transcript) (11.1.1)
# Requirement already satisfied: websockets<11.0,>=10.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html->llama-hub-youtube-transcript) (10.4)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (1.0.0)
# Requirement already satisfied: beautifulsoup4 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from bs4->requests-html->llama-hub-youtube-transcript) (4.12.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (3.22.0)
# Requirement already satisfied: anyio in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (4.6.0)
# Requirement already satisfied: httpcore==1.* in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (1.0.6)
# Requirement already satisfied: sniffio in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (0.14.0)
# Requirement already satisfied: lxml>=2.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from pyquery->requests-html->llama-hub-youtube-transcript) (5.3.0)
# Requirement already satisfied: cssselect>=1.2.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from pyquery->requests-html->llama-hub-youtube-transcript) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->llama-hub-youtube-transcript) (3.20.2)
# Requirement already satisfied: packaging>=17.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-youtube-transcript) (24.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from beautifulsoup4->bs4->requests-html->llama-hub-youtube-transcript) (2.6)
# Downloading llama_index_readers_youtube_transcript-0.2.0-py3-none-any.whl (3.6 kB)
# Downloading youtube_transcript_api-0.6.2-py3-none-any.whl (24 kB)
# Installing collected packages: youtube-transcript-api, llama-index-readers-youtube-transcript
# Successfully installed llama-index-readers-youtube-transcript-0.2.0 youtube-transcript-api-0.6.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# step2. 관련 라이브러리 불러오기

# %%
from llama_index.readers.youtube_transcript import YoutubeTranscriptReader

# %% [markdown]
# step3. 특정 유튜브 영상의 스크립트 정보 로드

# %%
loader = YoutubeTranscriptReader()
documents = loader.load_data(ytlinks=["https://www.youtube.com/watch?v=Oo8-nEuDBkk"])

print(documents)
# Out:
# [Document(id_='Oo8-nEuDBkk', embedding=None, metadata={'video_id': 'Oo8-nEuDBkk'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="today I'll be showing you how to build\nan AI web scraper using python that's\nright we'll be building an application\nthat can scrape literally any website\nusing AI this is super cool so let's\ndive in and let me give you a quick demo\nof how this application works so the\nfunctionality here is pretty basic all\nwe need to do is give it a website URL\nso maybe something like the metal table\nfrom the recent Olympics so let's paste\nthat right here we will scrape the site\ngrab the Dom content and then we can\npass a prompt to our AI that we'll be\nable to grab any information from this\nwebsite that we want all right so we\nhave our Dom content here this is all\nthe content from the site now I can\npaste in a prompt like give me a table\nthat contains all of the countries and\ntheir metal count we can wait a second\nand we'll get that information so there\nwe go we just got a table now that\ncontains a bunch of metal Counts from\nthe countries that were on that website\nlet's look at a few other examples then\ndive into the code and I'll show you\nexactly how we build something like this\nso here's a more e-commerce related\nexample it's a website called true\nclassic which actually has my favorite\nt-shirts and I'll show you how we can\nscrape this now and grab all of the\ndifferent T-shirts from this site so I'm\njust looking at the polo shirts here\nI'll paste in this URL scrape the site\nand then we'll give it a prompt and grab\nthat information so let's parse the\ncontent Now using this prompt and here\nyou go we get a result here with a few\ndifferent tables containing the\ndifferent products names their price\ncurrency ratings Etc lastly let's look\nat a real estate example you can see\nhere I have a property finder website\nfor properties into dub Marina which is\na place I'm going to be moving to\nshortly and if we scrape the site and\ngive it a prompt again we can get that\ndata and here you go we get a bunch of\ndifferent properties here with all of\ntheir relevant information all right so\nnow that we've looked at that demo we're\ngoing to start building out the project\nnow in order to do this we're going to\nneed to install a few different\ndependencies because we're going to be\nusing things like streamlit for the\nfront end we're going to be using\nselenium for actually doing the web\nscraping and then we're going to be\nusing Lang chain for actually calling\nthe AI and having the AI pars through\nour data so what we're going to do is\nset up a virtual environment here and\nnotice I've just opened up a new window\nin Visual Studio code so let's do that\nlet's install our dependencies and then\nwe'll start building this project so in\norder to do that I'm going to say Python\n3-m venv and then EnV or I can name this\nanything I want in this case I'm going\nto name it AI now if you're on Windows\nyou can simply replace Python 3 with\npython and this should spin up a new\nvirtual environment for you using ven V\nokay so let's hit enter here and now you\ncan see that we have a new one called AI\nnow we need to activate that virtual\nenvironment now if you're on Mac or\nLinux the command to do that will be\nSource the name of your virtual\nenvironment then slash bin and then\nslash activate when you do this you\nshould see that you get a prefix before\nyour commands line uh saying the name of\nthe virtual environment now if you're on\nWindows I'm going to show two commands\non screen right now that will show you\nhow to activate your virtual Environ\nenvironment they'll differ depending if\nyou're using CMD or Powershell so just\ntype that command in activate your\nvirtual environment and now we're going\nto install a few different dependencies\nnow all the dependencies that we need\nhave actually put up on GitHub so I'm\ngoing to link this in th ...

# %% [markdown]
# ### 3. Wikipedia Reader

# %% [markdown]
# step1. 관련 라이브러리 설치

# %%
pip install wikipedia llama-index-readers-wikipedia
# Out:
# Requirement already satisfied: wikipedia in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (1.4.0)
# Requirement already satisfied: llama-index-readers-wikipedia in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: beautifulsoup4 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from wikipedia) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from wikipedia) (2.32.3)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-readers-wikipedia) (0.11.17)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (3.10.8)
# Requirement already satisfied: dataclasses-json in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2024.9.0)
# Requirement already satisfied: httpx in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (3.3)
# Requirement already satisfied: nltk>3.8.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (0.9.0)
# Requirement already satisfied: wrapt in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from beautifulsoup4->wikipedia) (2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.13.1)
# Requirement already satisfied: click in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (8.1.7)
# Requirement already satisfied: joblib in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2.23.4)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (3.22.0)
# Requirement already satisfied: anyio in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (4.6.0)
# Requirement already satisfied: httpcore==1.* in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.0.6)
# Requirement already satisfied: sniffio in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /Users/sangwoo/Desktop/PYTHON BASIC/LLAMA_INDEX/llamaindex_tutorial/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (24.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# step2. 관련 라이브러리 불러오기

# %%
from llama_index.readers.wikipedia import WikipediaReader

# %% [markdown]
# step3. 특정 주제의 위키피디아 정보 로드

# %%
reader = WikipediaReader()

documents = reader.load_data(pages=["Python (programming language)"])

print(documents)
# Out:
# [Document(id_='23862', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation.\nPython is dynamically typed and garbage-collected. It supports multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming. It is often described as a "batteries included" language due to its comprehensive standard library.\nGuido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language and first released it in 1991 as Python 0.9.0. Python 2.0 was released in 2000. Python 3.0, released in 2008, was a major revision not completely backward-compatible with earlier versions. Python 2.7.18, released in 2020, was the last release of Python 2.\nPython consistently ranks as one of the most popular programming languages, and has gained widespread use in the machine learning community.\n\n\n== History ==\n\nPython was invented in the late 1980s by Guido van Rossum at Centrum Wiskunde & Informatica (CWI) in the Netherlands as a successor to the ABC programming language, which was inspired by SETL, capable of exception handling and interfacing with the Amoeba operating system. Its implementation began in December 1989. Van Rossum shouldered sole responsibility for the project, as the lead developer, until 12 July 2018, when he announced his "permanent vacation" from his responsibilities as Python\'s "benevolent dictator for life" (BDFL), a title the Python community bestowed upon him to reflect his long-term commitment as the project\'s chief decision-maker (he has since come out of retirement and is self-titled "BDFL-emeritus"). In January 2019, active Python core developers elected a five-member Steering Council to lead the project.\nPython 2.0 was released on 16 October 2000, with many major new features such as list comprehensions, cycle-detecting garbage collection, reference counting, and Unicode support. Python 3.0 was released on 3 December 2008, with many of its major features backported to Python 2.6.x and 2.7.x. Releases of Python 3 include the 2to3 utility, which automates the translation of Python 2 code to Python 3.\nPython 2.7\'s end-of-life was initially set for 2015, then postponed to 2020 out of concern that a large body of existing code could not easily be forward-ported to Python 3. No further security patches or other improvements will be released for it. Currently only 3.9 and later are supported (2023 security issues were fixed in e.g. 3.7.17, the final 3.7.x release). While Python 2.7 and older is officially unsupported, a different unofficial Python implementation, PyPy, continues to support Python 2, i.e. "2.7.18+" (plus 3.10), with the plus meaning (at least some) "backported security updates".\nIn 2021 (and again twice in 2022, and in September 2024 for Python 3.12.6 down to 3.8.20), security updates were expedited, since all Python versions were insecure (including 2.7) because of security issues leading to possible remote code execution and web-cache poisoning. In 2022, Python 3.10.4 and 3.9.12 were expedited and 3.8.13, because of many security issues. When Python 3.9.13 was released in May 2022, it was announced that the 3.9 series (joining the older series 3.8 and 3.7) would only receive security fixes in the future. On 7 September 2022, four new releases were made due to a potential denial-of-service attack: 3.10.7, 3.9.14, 3.8.14, and 3.7.14.\nEvery Python release since 3.5 has added some syntax to the language. 3.10 added the | union type operator and the match and case keywords (for structural pattern matching statements). 3.11 expanded exception handling functionality. Python 3.12 added the new keyword type. Notable changes in 3.11 from 3.10 include increased program execution speed and improved error report ...
